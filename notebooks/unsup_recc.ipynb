# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
from src.preprocessing import load_data, preprocess_movies
from src.recommendation import (
    build_content_matrix,
    compute_similarity_matrix,
    recommend_movies
)


df_raw = load_data("../data/movies.csv")
df = preprocess_movies(df_raw)


content = build_content_matrix(df)
similarity_matrix = compute_similarity_matrix(content)


recommend_movies("The Dark Knight", df, similarity_matrix, top_n=5)
# Out:
# d:\PROJECTS\MOVIE_RECC_PROJECT\movie_recc_system\src\preprocessing.py:42: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["release_date"] = pd.to_datetime(
#                                   title                       genres  \
# 3                 The Dark Knight Rises  Action Crime Drama Thriller
# 299                      Batman Forever         Action Crime Fantasy
# 428                      Batman Returns               Action Fantasy
# 119                       Batman Begins           Action Crime Drama
# 9    Batman v Superman: Dawn of Justice     Action Adventure Fantasy
#
#      vote_average
# 3             7.6
# 299           5.2
# 428           6.6
# 119           7.5
# 9             5.7
